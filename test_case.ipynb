# %%
#import cashier module and Transaction class in cashier module
from cashier import Transaction

#call Transaction class
trx = Transaction()
#call input_order and action_menu instances to perform the program
trx.input_order()
trx.action_menu()
# Out:
# Welcome to SUPERMARKET!
#
# Please enter your order here.
#
# Item Name: ayam goreng
# Quantity: 2
# Price: 20000
#
# Are there any other items? (Yes/No) yes
#
# Item Name: pasta gigi
# Quantity: 3
# Price: 15000
#
# Are there any other items? (Yes/No) no
#
#
#         Choose Menu Number:
#           1. Add More Item
#           2. Update Item Name
#           3. Update Item Quantity
#           4. Update Item Price
#           5. Delete Item
#           6. Reset Transaction
#           7. Check Order
#           8. Check Out
#
# Menu Number: 7
#
# Your Order List:
# +-------------+-----------------+--------------------+---------------------+
# | Item Name   |   Item Quantity |   Item Price (IDR) |   Total Price (IDR) |
# +=============+=================+====================+=====================+
# | Ayam Goreng |               2 |              20000 |               40000 |
# +-------------+-----------------+--------------------+---------------------+
# ...
